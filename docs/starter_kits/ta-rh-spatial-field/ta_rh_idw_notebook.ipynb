# %% [markdown]
# # A1 Ta/RH Spatial Field Notebook
#
# Run this notebook from the starter-kit folder. It reads `sample_points.csv`, creates an IDW field hypothesis, and writes gridded CSV/PNG outputs. The sampled points remain visible because interpolation is not measurement.

# %%
from pathlib import Path
import runpy

runpy.run_path(Path('ta_rh_idw_notebook.py'))

# %% [markdown]
# Inspect `outputs/ta_rh_idw_summary.csv` before using the field map in A1. If the leave-one-out error is large or the sampling layout is weak, the field should be described as a hypothesis rather than evidence of every location.

# %% [markdown]
# # A3 Degree-Hours Notebook
#
# Run this notebook from the starter-kit folder. It ingests the checked EnergyPlus CSV by default, calculates failure hours and degree-hours, and writes a plot plus summary CSVs.

# %%
from pathlib import Path
import runpy

runpy.run_path(Path('degree_hours_notebook.py'))

# %% [markdown]
# Change `A3_THRESHOLD_C`, `A3_VARIABLE_HINT`, or `A3_INPUT_CSV` if your project uses a different threshold, variable, or hourly data source.
